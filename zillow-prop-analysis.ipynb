# %%
# https://www.quandl.com/databases/ZILLOW/documentation?anchor=coverage-data-organization
import quandl
quandl.ApiConfig.api_key = 'E6J51HCy5xdAwGGeo6n9'
quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', region_id='99999')
# Out:
#      indicator_id region_id       date     value
# None
# 0            ZSFH     99999 2020-12-31  383138.0
# 1            ZSFH     99999 2020-11-30  378899.0
# 2            ZSFH     99999 2020-10-31  375825.0
# 3            ZSFH     99999 2020-09-30  369733.0
# 4            ZSFH     99999 2020-08-31  366760.0
# ...           ...       ...        ...       ...
# 187          ZSFH     99999 2005-05-31  169868.0
# 188          ZSFH     99999 2005-04-30  167105.0
# 189          ZSFH     99999 2005-03-31  165721.0
# 190          ZSFH     99999 2005-02-28  164998.0
# 191          ZSFH     99999 2005-01-31  164988.0
#
# [192 rows x 4 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
zillowdata = quandl.get_table('ZILLOW/DATA', indicator_id='ZSFH', region_id='99999')
zillowdata.plot()
# Out:
# <AxesSubplot:xlabel='None'>

# %%
quandl.get_table('ZILLOW/INDICATOR', indicator_id='ZSFH', region_id='99999')
# Out:
# ---------------------------------------------------------------------------
# ForbiddenError                            Traceback (most recent call last)
# <ipython-input-5-0591bc86950f> in <module>
# ----> 1 quandl.get_table('ZILLOW/INDICATOR', indicator_id='ZSFH', region_id='99999')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/quandl/model/datatable.py in data(self, **options)
#      29         if not options:
#      30             options = {'params': {}}
# ---> 31         return Data.page(self, **options)
#      32
#      33     def download_file(self, file_or_folder_path, **options):
#
# ...

# %%
quandl.get_table('ZILLOW/INDICATOR', indicator_id='ZSFH', region_id='99999')

# %%
# https://www.zillow.com/howto/api/GetSearchResults.htm
# https://pyzillow.readthedocs.io/en/latest/getting_started.html1
from pyzillow.pyzillow import ZillowWrapper
zillow_data = ZillowWrapper(X1-ZWz16srou6nkej_3e7gq)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-23debe4b99d7> in <module>
#       2 # https://pyzillow.readthedocs.io/en/latest/getting_started.html1
#       3 # from pyzillow.pyzillow import ZillowWrapper
# ----> 4 import pyzillow
#       5 zillow_data = ZillowWrapper(X1-ZWz16srou6nkej_3e7gq)
#
# ModuleNotFoundError: No module named 'pyzillow'
